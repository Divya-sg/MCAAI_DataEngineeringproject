# %% [markdown]
# #### Numpy array vs dask array

# %%
import numpy as np
images = np.ones((10000,10000,10000))
images

# %%
import dask.array as da
images = da.ones((10000,10000,10000))
images

# %% [markdown]
# #### Pandas Dataframe vs Dask Dataframe

# %%
#import pandas as pd
#df = pd.read_parquet("s3://dask-data/nyc-taxi/nyc-2015.parquet/part.*.parquet",columns=["passenger_count","tip_amount"])
#df.head()

# %%
import dask.dataframe as dd
dd = dd.read_parquet("s3://dask-data/nyc-taxi/nyc-2015.parquet/part.1.parquet", 
                     columns=["passenger_count","tip_amount"],
                     storage_options={"anon":True})
dd.head()

# %% [markdown]
# #### Dask Distributed

# %%
from dask.distributed import LocalCluster, Client

# %%
client = Client(n_workers=4)
client
# Out:
# <Client: 'tcp://127.0.0.1:51401' processes=4 threads=8, memory=16.00 GiB>

# %%
import os
import dask

# %%
import dask.dataframe as dd

ddf = dd.read_csv(
    os.path.join("data", "nycflights", "*.csv"), parse_dates={"Date": [0, 1, 2]}
)
ddf
# Out:
# Dask DataFrame Structure:
#                           Date DayOfWeek  DepTime CRSDepTime  ArrTime CRSArrTime UniqueCarrier FlightNum  TailNum ActualElapsedTime CRSElapsedTime  AirTime ArrDelay DepDelay  Origin    Dest Distance   TaxiIn  TaxiOut Cancelled Diverted
# npartitions=10
#                 datetime64[ns]     int64  float64      int64  float64      int64        object     int64  float64           float64          int64  float64  float64  float64  object  object  float64  float64  float64     int64    int64
#                            ...       ...      ...        ...      ...        ...           ...       ...      ...               ...            ...      ...      ...      ...     ...     ...      ...      ...      ...       ...      ...
# ...                        ...       ...      ...        ...      ...        ...           ...       ...      ...               ...            ...      ...      ...      ...     ...     ...      ...      ...      ...       ...      ...
# ...

# %%
ddf.visualize()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/graphviz/backend/execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78                 kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79             proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/graphviz/backend/execute.py in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     100
#
# ...

# %%
#import dask
#import json
#import os

#os.makedirs('data', exist_ok=True)              # Create data/ directory

b = dask.datasets.make_people()                 # Make records of people
#b.map(json.dumps).to_textfiles('data/*.json')   # Encode as JSON, write to disk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/dask/utils.py in import_required(mod_name, error_msg)
#     160     try:
# --> 161         return import_module(mod_name)
#     162     except ImportError as e:
#
# ~/opt/anaconda3/lib/python3.9/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ~/opt/anaconda3/lib/python3.9/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/opt/anaconda3/lib/python3.9/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/opt/anaconda3/lib/python3.9/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'mimesis'
#
# The above exception was the direct cause of the following exception:
#
# ...
